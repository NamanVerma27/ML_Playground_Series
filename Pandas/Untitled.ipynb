# %%
import numpy as np
import pandas as pd

# %%
company=pd.read_csv('Fortune500.csv')
company.head()
# Out:
#                          name  rank  year                industry sector  \
# 0  General Motors Corporation     1  1996  Motor Vehicles & Parts    NaN
# 1          Ford Motor Company     2  1996  Motor Vehicles & Parts    NaN
# 2           Exxon Corporation     3  1996      Petroleum Refining    NaN
# 3       Wal-Mart Stores, Inc.     4  1996   General Merchandisers    NaN
# 4                  AT&T Corp.     5  1996      Telecommunications    NaN
#
#   headquarters_state headquarters_city  market_value_mil  revenue_mil  \
# 0                 MI               NaN               NaN     168828.6
# 1                 MI               NaN               NaN     137137.0
# 2                 TX               NaN               NaN     110009.0
# 3                 AR               NaN               NaN      93627.0
# 4                 NY               NaN               NaN      79609.0
#
#    profit_mil  asset_mil  employees founder_is_ceo female_ceo  \
# ...

# %%
ind=company.groupby('industry')

# %%
len(company)
# Out:
# 13940

# %%
len(ind)
# Out:
# 94

# %%
ind.size().sort_values(ascending=False)
# Out:
# industry
# Utilities: Gas and Electric                 753
# Commercial Banks                            590
# Insurance: Property and Casualty (Stock)    497
# Chemicals                                   420
# Motor Vehicles & Parts                      385
#                                            ...
# Payroll Services                              5
# X Brokerage                                   5
# Equipment Leasing                             4
# Education                                     3
# Marine services                               2
# Length: 94, dtype: int64

# %%
ind.first()
# Out:
#                                                                         name  \
# industry
# Advertising, Marketing                                    Omnicom Group Inc.
# Aerospace & Defense                              Lockheed Martin Corporation
# Airlines                                                     AMR Corporation
# Apparel                                              Levi Strauss Associates
# Automotive Retailing, Services                                  Ryder System
# ...                                                                      ...
# Wholesalers: Electronics and Office Equipment             Ingram Micro, Inc.
# Wholesalers: Food and Grocery                                 Supervalu Inc.
# Wholesalers: Health Care                                  McKesson HBOC Inc.
# X Brokerage                                    Merrill Lynch & Company, Inc.
# zMiscellaneous                                                 ServiceMaster
#
# ...

# %%
ind.last()
# Out:
#                                                                            name  \
# industry
# Advertising, Marketing                                        Interpublic Group
# Aerospace & Defense                               Huntington Ingalls Industries
# Airlines                                                        JetBlue Airways
# Apparel                                                         Skechers U.S.A.
# Automotive Retailing, Services                            Hertz Global Holdings
# ...                                                                         ...
# Wholesalers: Electronics and Office Equipment                             Avnet
# Wholesalers: Food and Grocery                                       SpartanNash
# Wholesalers: Health Care                                          Owens & Minor
# X Brokerage                                    The Bear Stearns Companies, Inc.
# zMiscellaneous                                           A-Mark Precious Metals
#
# ...

# %%
ind.groups
# Out:
# {'Advertising, Marketing': [977, 1275, 1438, 1439, 1857, 1866, 2292, 2323, 2744, 2757, 3229, 3236, 3702, 3737, 4190, 4254, 4677, 4778, 5170, 5292, 5664, 5811, 6154, 6315, 6644, 6802, 7139, 7299, 7636, 7795, 8136, 8297, 8630, 8805, 9140, 9308, 9639, 9811, 10125, 10294, 10618, 10784, 11127, 11298, 11645, 11761, 12150, 12247, 12668, 12773, 13194, 13292, 13729, 13810], 'Aerospace & Defense': [28, 29, 39, 72, 73, 127, 187, 345, 516, 524, 526, 576, 645, 670, 860, 995, 1016, 1024, 1075, 1131, 1151, 1346, 1395, 1487, 1519, 1521, 1548, 1578, 1623, 1659, 1796, 1867, 1987, 2028, 2033, 2041, 2058, 2127, 2162, 2163, 2273, 2485, 2533, 2538, 2540, 2579, 2617, 2646, 2698, 2786, 2979, 3021, 3039, 3044, 3080, 3111, 3124, 3125, 3296, 3470, 3504, 3511, 3533, 3554, 3560, 3592, 3629, 3839, 3852, 3974, 4001, 4004, 4008, 4029, 4060, 4074, 4145, 4299, 4344, 4474, 4488, 4495, 4506, 4523, 4551, 4563, 4663, 4751, 4853, 4971, 4988, 4997, 5012, 5016, 5042, 5045, 5135, 5198, 5346, 5472, ...], 'Airlines': [52, 69, 
# ...

# %%
ind.get_group('Energy').shape
# Out:
# (189, 16)

# %%
ind.sum()
# Out:
#                                                                                             name  \
# industry
# Advertising, Marketing                         Omnicom Group Inc.Cendant CorporationInterpubl...
# Aerospace & Defense                            Lockheed Martin CorporationUnited Technologies...
# Airlines                                       AMR CorporationUAL CorporationDelta Air Lines,...
# Apparel                                        Levi Strauss AssociatesVF CorporationNike, Inc...
# Automotive Retailing, Services                 Ryder SystemRyder System, Inc.Ryder System, In...
# ...                                                                                          ...
# Wholesalers: Electronics and Office Equipment  Ingram Micro, Inc.Tech Data CorporationArrow E...
# Wholesalers: Food and Grocery                  Supervalu Inc.Sysco CorporationFleming Compani...
# ...

# %%
ind['revenue_mil'].mean().sort_values(ascending=False)
# Out:
# industry
# Wholesalers: Health Care                    70430.663565
# Petroleum Refining                          67038.146409
# General Merchandisers                       55990.225619
# Health Care: Insurance and Managed Care     47663.628718
# Health Care: Pharmacy and Other Services    43312.244063
#                                                 ...
# Education                                    4781.633333
# Furniture                                    4181.371429
# Textiles                                     3862.663636
# Trucking                                     3776.453846
# Marine services                              2817.550000
# Name: revenue_mil, Length: 94, dtype: float64
